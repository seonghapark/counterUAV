# %%
import glob
import os
import random
import librosa
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
# %matplotlib inline
plt.style.use('ggplot')

# %%
def windows(data, window_size):
    start = 0
    while start < len(data):
        yield start, start + window_size
        start += (window_size / 2)

# 각 33개 input, 각 6개 label
        
def extract_features(file_path, file_label, file_ext="*.wav",bands = 20, frames = 41):
    window_size = 512 * (frames - 1)
    mfccs = []
    log_specgrams = []
    features = []
    labels = []
    sound_clip, s = librosa.load(file_path)
    #print(type(sound_clip))
    if file_label=='other':
        label_code = 0
    elif file_label=='person':
        label_code = 1
    elif file_label=='car':
        label_code = 2
    elif file_label=='drone':
        label_code = 3
        
        
    #print(file_label, label_code)
    for (start,end) in windows(sound_clip,window_size):
        start = int(start)
        end = int(end)
        if(len(sound_clip[start:end]) == window_size):
            signal = sound_clip[start:end]
            
            melspec = librosa.feature.melspectrogram(signal, n_mels = bands)
            logspec = librosa.amplitude_to_db(melspec)
            logspec = logspec.T.flatten()[:, np.newaxis].T
            #print(1, logspec.shape)
            log_specgrams.append(logspec)
            
            mfcc = librosa.feature.mfcc(y=signal, sr=s, n_mfcc = bands).T.flatten()[:, np.newaxis].T
            mfccs.append(mfcc)
            #print(2, mfcc.shape)
            features = np.hstack((mfccs, log_specgrams))
            labels.append(label_code)         
    features = np.asarray(features).reshape(len(mfccs), frames, bands*2)
    #print(features.shape)
    return np.array(features), np.array(labels,dtype = np.int)

def extract_features_for_predict(file_path, bands = 20, frames = 41):
    window_size = 512 * (frames - 1)
    mfccs = []
    log_specgrams = []
    features = []
    sound_clip, s = librosa.load(file_path)
    
    for (start,end) in windows(sound_clip,window_size):
        start = int(start)
        end = int(end)
        if(len(sound_clip[start:end]) == window_size):
            signal = sound_clip[start:end]
            
            melspec = librosa.feature.melspectrogram(signal, n_mels = bands)
            logspec = librosa.amplitude_to_db(melspec)
            logspec = logspec.T.flatten()[:, np.newaxis].T
            log_specgrams.append(logspec)
            
            mfcc = librosa.feature.mfcc(y=signal, sr=s, n_mfcc = bands).T.flatten()[:, np.newaxis].T
            mfccs.append(mfcc)
            features = np.hstack((mfccs, log_specgrams))      
            
    features = np.asarray(features).reshape(len(mfccs), frames, bands*2)
    #print(features.shape)
    return np.array(features)

def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1
    return one_hot_encode

# %%
wav_file_path_training = 'C://slice_wav_data/training/'
file_list_training = os.listdir(wav_file_path_training)

tr_features = []
tr_labels = []
for f in file_list_training:
    file_label = f.split("_")[0]
    #if file_label=='person' or file_label=='car': ## 2개씩만 하는 코드
     #   continue
    features_temp, labels_temp = extract_features(wav_file_path_training + f, file_label)
    for tr_f in features_temp:
        tr_features.append(tr_f)
    for tr_l in labels_temp:
        tr_labels.append(tr_l)
    

tmp = [[x,y] for x,y in zip(tr_features, tr_labels)]
random.shuffle(tmp)
tr_features = [n[0] for n in tmp]
tr_labels = [n[1] for n in tmp]


wav_file_path_test = 'C://slice_wav_data/testing/'
file_list_test = os.listdir(wav_file_path_test)

ts_features = []
ts_labels = []
for f in file_list_test:
    file_label = f.split("_")[0]
    #if file_label=='person' or file_label=='car': ## 2개씩만 하는 코드
     #   continue
    features_temp, labels_temp = extract_features(wav_file_path_test + f, file_label)
    for ts_f in features_temp:
        ts_features.append(ts_f)
    for ts_l in labels_temp:
        ts_labels.append(ts_l)
    
tr_labels = one_hot_encode(tr_labels)
ts_labels = one_hot_encode(ts_labels)

tr_features = np.array(tr_features)
tr_labels = np.array(tr_labels)

ts_features = np.array(ts_features)
ts_labels = np.array(ts_labels)

# %%
temp_arr = np.array(tr_features)
temp_arr.shape
# Out:
# (1188, 41, 40)

# %%
temp_arr = np.array(ts_labels) #mfcc를 통해 1188개 트레이닝 데이터, 216개 테스팅 데이터로 변환
temp_arr.shape
# Out:
# (216, 4)

# %%
tf.reset_default_graph()

learning_rate = 0.0004
training_iters = 20000
batch_size = 54 #1188과 216의 최대공약수는 54
display_step = 200

# Network Parameters
n_input = 40
n_steps = 41
n_hidden = 40
n_classes = 4

#앞에거는 hidden *2, 뒤에거는 n_input + n_hidden

x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

weight = tf.Variable(tf.random_normal([n_hidden, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))
# Out:
# WARNING:tensorflow:From C:\Users\kvlks\Miniconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def RNN(x, weight, bias):
    cell = rnn_cell.LSTMCell(n_hidden,state_is_tuple = True)
    cell = rnn_cell.MultiRNNCell([cell] * 8, state_is_tuple=True)
    output, state = tf.nn.dynamic_rnn(cell, x, dtype = tf.float32)
    print(1, output)
    output = tf.transpose(output, [1, 0, 2])
    print(1, output)
    last = tf.gather(output, int(output.get_shape()[0]) - 1)
    print(output.get_shape())
    print(1, last)
    return tf.nn.softmax(tf.matmul(last, weight) + bias)

# %%
prediction = RNN(x, weight, bias)
print(prediction)

prediction_str = tf.argmax(prediction, 1)
#prediction_str = tf.argmax(prediction)

# Define loss and optimizer
loss_f = -tf.reduce_sum(y * tf.log(prediction))
optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss_f)

# Evaluate model
correct_pred = tf.equal(tf.argmax(prediction,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-7-1f170cd6f0b8>:2: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-7-1f170cd6f0b8>:3: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:At least two cells provided to MultiRNNCell are the same object and will share weights.
# WARNING:tensorflow:From <ipython-input-7-1f170cd6f0b8>:4: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# 1 Tensor("rnn/transpose_1:0", shape=(?, 41, 40), dtype=float32)
# 1 Tensor("transpose:0", shape=(41, ?, 40), dtype=float32)
# (41, ?, 40)
# 1 Tensor("GatherV2:0", shape=(?, 40), dtype=float32)
# Tensor("Softmax:0", shape=(?, 4), dtype=float32)
# WARNING:tensorflow:From C:\Users\kvlks\Miniconda3\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\kvlks\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
session = tf.Session()
session.run(init)
    
training_epochs = 10000
for epoch in range(training_epochs):
    avg_cost = 0
    total_batch = int(len(tr_features) / batch_size)
 
    for i in range(total_batch):
        start = ((i+1) * batch_size) - batch_size
        end = ((i+1) * batch_size)
        batch_x = tr_features[start:end]
        batch_y = tr_labels[start:end]
                
        _, c = session.run([optimizer, loss_f], feed_dict={x: batch_x, y : batch_y})
        avg_cost += c / total_batch
 
    print('Epoch:', '%04d' % (epoch + 1), 'cost =', '{:.9f}'.format(avg_cost), end='')
    print('Test accuracy: ',round(session.run(accuracy, feed_dict={x: ts_features, y: ts_labels}) , 3))
print('Learning Finished!')
# Out:
# Epoch: 0001 cost = 89.814955625Test accuracy:  0.264
# Epoch: 0002 cost = 75.129258936Test accuracy:  0.259
# Epoch: 0003 cost = 71.766682712Test accuracy:  0.162
# Epoch: 0004 cost = 66.888124466Test accuracy:  0.25
# Epoch: 0005 cost = 63.035421718Test accuracy:  0.273
# Epoch: 0006 cost = 59.330391624Test accuracy:  0.347
# Epoch: 0007 cost = 58.454699430Test accuracy:  0.273
# Epoch: 0008 cost = 56.160501133Test accuracy:  0.292
# Epoch: 0009 cost = 55.095351999Test accuracy:  0.329
# Epoch: 0010 cost = 52.418754924Test accuracy:  0.5
# Epoch: 0011 cost = 47.629983729Test accuracy:  0.454
# Epoch: 0012 cost = 42.585150979Test accuracy:  0.44
# Epoch: 0013 cost = 39.765633323Test accuracy:  0.477
# Epoch: 0014 cost = 38.018416231Test accuracy:  0.495
# Epoch: 0015 cost = 36.512323293Test accuracy:  0.532
# Epoch: 0016 cost = 35.387279684Test accuracy:  0.569
# Epoch: 0017 cost = 35.003973181Test accuracy:  0.593
# Epoch: 0018 cost = 33.552373626Test accuracy:  0.597
# Epoch: 0019 cost = 32.942707322Test accuracy:  0.648
# Epoch: 0020 cost = 31.421757525Test accuracy:  0.634
# Epoch: 0021 cost = 30.738615469Test accuracy:  0.625
# Epoch: 0022 cost = 29.834532738Test accuracy:  0.644
# Epoch: 0023 cost = 29.855857762Test accuracy:  0.62
# Epoch: 0024 cost = 28.960889036Test accuracy:  0.634
# Epoch: 0025 cost = 28.984577439Test accuracy:  0.63
# Epoch: 0026 cost = 27.948329405Test accuracy:  0.62
# Epoch: 0027 cost = 29.687013886Test accuracy:  0.63
# Epoch: 0028 cost = 30.324416161Test accuracy:  0.602
# Epoch: 0029 cost = 28.369349306Test accuracy:  0.634
# Epoch: 0030 cost = 27.733823603Test accuracy:  0.588
# Epoch: 0031 cost = 28.606402917Test accuracy:  0.597
# Epoch: 0032 cost = 29.999025085Test accuracy:  0.588
# Epoch: 0033 cost = 28.934615309Test accuracy:  0.597
# Epoch: 0034 cost = 26.906359499Test accuracy:  0.579
# Epoch: 0035 cost = 26.156375365Test accuracy:  0.593
# Epoch: 0036 cost = 26.490512848Test accuracy:  0.565
# Epoch: 0037 cost = 26.381213188Test accuracy:  0.602
# Epoch: 0038 cost = 25.093820832Test accuracy:  0.556
# Epoch: 0039 cost = 25.040194858Test accuracy:  0.523
# Epoch: 0040 cost = 25.054447434Test accuracy:  0.546
# Epoch: 0041 cost = 25.687499567Test accuracy:  0.486
# Epoch: 0042 cost = 25.811451652Test accuracy:  0.551
# Epoch: 0043 cost = 25.895424149Test accuracy:  0.509
# Epoch: 0044 cost = 26.238668615Test accuracy:  0.551
# Epoch: 0045 cost = 26.406437700Test accuracy:  0.537
# Epoch: 0046 cost = 24.271409121Test accuracy:  0.574
# Epoch: 0047 cost = 24.051792838Test accuracy:  0.565
# Epoch: 0048 cost = 26.115618446Test accuracy:  0.505
# Epoch: 0049 cost = 23.902217778Test accuracy:  0.565
# Epoch: 0050 cost = 23.087109046Test accuracy:  0.532
# Epoch: 0051 cost = 24.463461182Test accuracy:  0.523
# Epoch: 0052 cost = 23.241760341Test accuracy:  0.532
# Epoch: 0053 cost = 22.551459139Test accuracy:  0.583
# Epoch: 0054 cost = 23.665105169Test accuracy:  0.509
# Epoch: 0055 cost = 22.952652671Test accuracy:  0.556
# Epoch: 0056 cost = 24.034941066Test accuracy:  0.56
# Epoch: 0057 cost = 22.664103248Test accuracy:  0.546
# Epoch: 0058 cost = 23.820389227Test accuracy:  0.537
# Epoch: 0059 cost = 22.245094689Test accuracy:  0.569
# Epoch: 0060 cost = 20.779235146Test accuracy:  0.546
# Epoch: 0061 cost = 21.652225191Test accuracy:  0.565
# Epoch: 0062 cost = 22.097241185Test accuracy:  0.56
# Epoch: 0063 cost = 21.121279977Test accuracy:  0.565
# Epoch: 0064 cost = 19.940234444Test accuracy:  0.565
# Epoch: 0065 cost = 20.456802932Test accuracy:  0.542
# Epoch: 0066 cost = 21.082463221Test accuracy:  0.551
# Epoch: 0067 cost = 20.090769985Test accuracy:  0.574
# Epoch: 0068 cost = 21.518579310Test accuracy:  0.546
# Epoch: 0069 cost = 20.254934398Test accuracy:  0.565
# Epoch: 0070 cost = 21.534181421Test accuracy:  0.551
# Epoch: 0071 cost = 21.204721451Test accuracy:  0.579
# Epoch: 0072 cost = 21.429265109Test accuracy:  0.542
# Epoch: 0073 cost = 19.683304960Test accuracy:  0.579
# Epoch: 0074 cost = 20.911314097Test accuracy:  0.528
# Epoch: 0075 cost = 22.751014536Test accuracy:  0.565
# Epoch: 0076 cost = 21.619172053Test accuracy:  0.593
# Epoch: 0077 cost = 21.065220486Test accuracy:  0.593
# Epoch: 0078 cost = 21.087046016Test accuracy:  0.574
# Epoch: 0079 cost = 23.093026465Test accuracy:  0.537
# Epoch: 0080 cost = 21.377886122Test accuracy:  0.542
# Epoch: 0081 cost = 19.694597721Test accuracy:  0.569
# Epoch: 0082 cost = 21.310965885Test accuracy:  0.546
# Epoch: 0083 cost = 18.613131913Test accuracy:  0.532
# Epoch: 0084 cost = 18.706265796Test accuracy:  0.569
# Epoch: 0085 cost = 18.587387518Test accuracy:  0.569
# Epoch: 0086 cost = 19.237338760Test accuracy:  0.606
# Epoch: 0087 cost = 19.190415426Test accuracy:  0.569
# Epoch: 0088 cost = 18.313413750Test accuracy:  0.56
# Epoch: 0089 cost = 17.355163748Test accuracy:  0.565
# Epoch: 0090 cost = 18.748503425Test accuracy:  0.583
# Epoch: 0091 cost = 16.712028937Test accuracy:  0.593
# Epoch: 0092 cost = 16.556735776Test accuracy:  0.574
# Epoch: 0093 cost = 16.110370723Test accuracy:  0.528
# Epoch: 0094 cost = 16.201679360Test accuracy:  0.579
# Epoch: 0095 cost = 19.331969435Test accuracy:  0.565
# Epoch: 0096 cost = 18.355386257Test accuracy:  0.56
# Epoch: 0097 cost = 17.526200121Test accuracy:  0.569
# Epoch: 0098 cost = 15.515233127Test accuracy:  0.583
# Epoch: 0099 cost = 15.360627261Test accuracy:  0.519
# Epoch: 0100 cost = 19.304972779Test accuracy:  0.528
# Epoch: 0101 cost = 19.326032465Test accuracy:  0.56
# Epoch: 0102 cost = 16.628464525Test accuracy:  0.583
# Epoch: 0103 cost = 17.432599588Test accuracy:  0.514
# Epoch: 0104 cost = 16.471404206Test accuracy:  0.593
# Epoch: 0105 cost = 14.928815668Test accuracy:  0.56
# Epoch: 0106 cost = 15.119511821Test accuracy:  0.551
# Epoch: 0107 cost = 14.729665323Test accuracy:  0.606
# Epoch: 0108 cost = 15.170155092Test accuracy:  0.546
# Epoch: 0109 cost = 19.591894540Test accuracy:  0.477
# Epoch: 0110 cost = 28.493000897Test accuracy:  0.542
# Epoch: 0111 cost = 16.998490464Test accuracy:  0.597
# Epoch: 0112 cost = 16.218235623Test accuracy:  0.551
# Epoch: 0113 cost = 15.881390615Test accuracy:  0.528
# Epoch: 0114 cost = 16.723962394Test accuracy:  0.606
# Epoch: 0115 cost = 16.146333434Test accuracy:  0.574
# Epoch: 0116 cost = 15.257402550Test accuracy:  0.537
# Epoch: 0117 cost = 15.623781118Test accuracy:  0.565
# Epoch: 0118 cost = 14.479115573Test accuracy:  0.509
# Epoch: 0119 cost = 13.693075267Test accuracy:  0.542
# Epoch: 0120 cost = 13.894923123Test accuracy:  0.481
# Epoch: 0121 cost = 15.352236401Test accuracy:  0.565
# Epoch: 0122 cost = 14.989459493Test accuracy:  0.597
# Epoch: 0123 cost = 16.130780003Test accuracy:  0.454
# Epoch: 0124 cost = 16.399255644Test accuracy:  0.574
# Epoch: 0125 cost = 13.886666515Test accuracy:  0.523
# Epoch: 0126 cost = 14.843116002Test accuracy:  0.565
# Epoch: 0127 cost = 15.759407000Test accuracy:  0.634
# Epoch: 0128 cost = 16.398625027Test accuracy:  0.588
# Epoch: 0129 cost = 14.243847327Test accuracy:  0.551
# Epoch: 0130 cost = 16.763818134Test accuracy:  0.602
# Epoch: 0131 cost = 14.455249071Test accuracy:  0.519
# Epoch: 0132 cost = 14.487875353Test accuracy:  0.519
# Epoch: 0133 cost = 14.384491097Test accuracy:  0.546
# Epoch: 0134 cost = 16.023618200Test accuracy:  0.63
# Epoch: 0135 cost = 15.090417168Test accuracy:  0.509
# Epoch: 0136 cost = 16.937262622Test accuracy:  0.551
# Epoch: 0137 cost = 16.354161566Test accuracy:  0.519
# Epoch: 0138 cost = 14.782314517Test accuracy:  0.514
# Epoch: 0139 cost = 16.033707445Test accuracy:  0.542
# Epoch: 0140 cost = 15.746065877Test accuracy:  0.602
# Epoch: 0141 cost = 13.068781419Test accuracy:  0.593
# Epoch: 0142 cost = 12.736790028Test accuracy:  0.542
# Epoch: 0143 cost = 13.718662045Test accuracy:  0.523
# Epoch: 0144 cost = 13.035176451Test accuracy:  0.583
# Epoch: 0145 cost = 11.784559943Test accuracy:  0.602
# Epoch: 0146 cost = 11.747976585Test accuracy:  0.542
# Epoch: 0147 cost = 13.268589757Test accuracy:  0.546
# Epoch: 0148 cost = 13.707392432Test accuracy:  0.593
# Epoch: 0149 cost = 13.120977098Test accuracy:  0.583
# Epoch: 0150 cost = 12.058882085Test accuracy:  0.606
# Epoch: 0151 cost = 11.525446198Test accuracy:  0.579
# Epoch: 0152 cost = 11.592595946Test accuracy:  0.579
# Epoch: 0153 cost = 11.294505488Test accuracy:  0.574
# Epoch: 0154 cost = 13.588486693Test accuracy:  0.537
# Epoch: 0155 cost = 12.531407400Test accuracy:  0.583
# Epoch: 0156 cost = 12.639805815Test accuracy:  0.556
# Epoch: 0157 cost = 12.222450712Test accuracy:  0.602
# Epoch: 0158 cost = 13.182252645Test accuracy:  0.579
# Epoch: 0159 cost = 13.578895547Test accuracy:  0.611
# Epoch: 0160 cost = 13.279055964Test accuracy:  0.509
# Epoch: 0161 cost = 12.611089663Test accuracy:  0.597
# Epoch: 0162 cost = 11.823019223Test accuracy:  0.583
# Epoch: 0163 cost = 10.232620543Test accuracy:  0.616
# Epoch: 0164 cost = 10.751374483Test accuracy:  0.606
# Epoch: 0165 cost = 11.083569538Test accuracy:  0.62
# Epoch: 0166 cost = 10.611087214Test accuracy:  0.634
# Epoch: 0167 cost = 10.965623032Test accuracy:  0.583
# Epoch: 0168 cost = 12.214343136Test accuracy:  0.579
# Epoch: 0169 cost = 13.772648681Test accuracy:  0.625
# Epoch: 0170 cost = 18.260828387Test accuracy:  0.56
# Epoch: 0171 cost = 16.691630970Test accuracy:  0.537
# Epoch: 0172 cost = 11.492864219Test accuracy:  0.583
# Epoch: 0173 cost = 10.589109898Test accuracy:  0.537
# Epoch: 0174 cost = 12.548055692Test accuracy:  0.597
# Epoch: 0175 cost = 10.626251849Test accuracy:  0.579
# Epoch: 0176 cost = 14.044034438Test accuracy:  0.565
# Epoch: 0177 cost = 14.250722300Test accuracy:  0.606
# Epoch: 0178 cost = 14.405802445Test accuracy:  0.551
# Epoch: 0179 cost = 13.734155590Test accuracy:  0.62
# Epoch: 0180 cost = 12.913243337Test accuracy:  0.569
# Epoch: 0181 cost = 12.752833692Test accuracy:  0.616
# Epoch: 0182 cost = 11.142027898Test accuracy:  0.509
# Epoch: 0183 cost = 10.651261178Test accuracy:  0.63
# Epoch: 0184 cost = 10.856164911Test accuracy:  0.56
# Epoch: 0185 cost = 12.720977783Test accuracy:  0.62
# Epoch: 0186 cost = 12.904397813Test accuracy:  0.574
# Epoch: 0187 cost = 13.415883194Test accuracy:  0.407
# Epoch: 0188 cost = 13.578468063Test accuracy:  0.63
# Epoch: 0189 cost = 12.440784216Test accuracy:  0.63
# Epoch: 0190 cost = 13.211687348Test accuracy:  0.63
# Epoch: 0191 cost = 13.696823554Test accuracy:  0.565
# Epoch: 0192 cost = 16.710029754Test accuracy:  0.593
# Epoch: 0193 cost = 14.751147053Test accuracy:  0.593
# Epoch: 0194 cost = 11.429761128Test accuracy:  0.569
# Epoch: 0195 cost = 10.454079151Test accuracy:  0.579
# Epoch: 0196 cost = 10.355592251Test accuracy:  0.616
# Epoch: 0197 cost = 9.655218038Test accuracy:  0.625
# Epoch: 0198 cost = 9.865112933Test accuracy:  0.56
# Epoch: 0199 cost = 9.769283121Test accuracy:  0.616
# Epoch: 0200 cost = 11.943909082Test accuracy:  0.611
# Epoch: 0201 cost = 10.377356464Test accuracy:  0.606
# Epoch: 0202 cost = 10.601781368Test accuracy:  0.514
# Epoch: 0203 cost = 11.016299183Test accuracy:  0.602
# Epoch: 0204 cost = 9.547375050Test accuracy:  0.62
# Epoch: 0205 cost = 11.014765447Test accuracy:  0.546
# Epoch: 0206 cost = 10.282435027Test accuracy:  0.639
# Epoch: 0207 cost = 9.727839112Test accuracy:  0.634
# Epoch: 0208 cost = 10.004323862Test accuracy:  0.602
# Epoch: 0209 cost = 9.981117920Test accuracy:  0.593
# Epoch: 0210 cost = 9.707074686Test accuracy:  0.625
# Epoch: 0211 cost = 8.907634540Test accuracy:  0.616
# Epoch: 0212 cost = 10.628226952Test accuracy:  0.606
# Epoch: 0213 cost = 8.718167738Test accuracy:  0.63
# Epoch: 0214 cost = 12.994076057Test accuracy:  0.481
# Epoch: 0215 cost = 12.791648973Test accuracy:  0.551
# Epoch: 0216 cost = 21.880664479Test accuracy:  0.412
# Epoch: 0217 cost = 24.435064923Test accuracy:  0.579
# Epoch: 0218 cost = 12.259828741Test accuracy:  0.63
# Epoch: 0219 cost = 10.068316135Test accuracy:  0.625
# Epoch: 0220 cost = 10.152092999Test accuracy:  0.639
# Epoch: 0221 cost = 8.933869123Test accuracy:  0.62
# Epoch: 0222 cost = 9.594492262Test accuracy:  0.639
# Epoch: 0223 cost = 9.060846079Test accuracy:  0.625
# Epoch: 0224 cost = 9.502310677Test accuracy:  0.597
# Epoch: 0225 cost = 9.828953201Test accuracy:  0.579
# Epoch: 0226 cost = 8.533983198Test accuracy:  0.611
# Epoch: 0227 cost = 8.685490522Test accuracy:  0.616
# Epoch: 0228 cost = 10.114747362Test accuracy:  0.625
# Epoch: 0229 cost = 8.418487267Test accuracy:  0.602
# Epoch: 0230 cost = 8.174773357Test accuracy:  0.616
# Epoch: 0231 cost = 8.333308187Test accuracy:  0.625
# Epoch: 0232 cost = 8.616379239Test accuracy:  0.602
# Epoch: 0233 cost = 8.596544743Test accuracy:  0.639
# Epoch: 0234 cost = 8.211430701Test accuracy:  0.588
# Epoch: 0235 cost = 9.339448929Test accuracy:  0.597
# Epoch: 0236 cost = 8.512892875Test accuracy:  0.653
# Epoch: 0237 cost = 12.135550109Test accuracy:  0.611
# Epoch: 0238 cost = 9.504698482Test accuracy:  0.579
# Epoch: 0239 cost = 11.960334399Test accuracy:  0.542
# Epoch: 0240 cost = 17.749214736Test accuracy:  0.583
# Epoch: 0241 cost = 13.230614521Test accuracy:  0.662
# Epoch: 0242 cost = 9.175034523Test accuracy:  0.597
# Epoch: 0243 cost = 8.895936186Test accuracy:  0.644
# Epoch: 0244 cost = 8.379739469Test accuracy:  0.611
# Epoch: 0245 cost = 9.481850472Test accuracy:  0.616
# Epoch: 0246 cost = 8.884601409Test accuracy:  0.648
# Epoch: 0247 cost = 7.950733272Test accuracy:  0.63
# Epoch: 0248 cost = 8.433428450Test accuracy:  0.611
# Epoch: 0249 cost = 8.622541623Test accuracy:  0.648
# Epoch: 0250 cost = 11.078934572Test accuracy:  0.606
# Epoch: 0251 cost = 14.175199574Test accuracy:  0.579
# Epoch: 0252 cost = 23.867270123Test accuracy:  0.528
# Epoch: 0253 cost = 14.533692403Test accuracy:  0.546
# Epoch: 0254 cost = 9.638348742Test accuracy:  0.634
# Epoch: 0255 cost = 8.559361295Test accuracy:  0.602
# Epoch: 0256 cost = 8.484080011Test accuracy:  0.634
# Epoch: 0257 cost = 8.345543666Test accuracy:  0.611
# Epoch: 0258 cost = 8.988768729Test accuracy:  0.63
# Epoch: 0259 cost = 8.221501329Test accuracy:  0.639
# Epoch: 0260 cost = 8.892577453Test accuracy:  0.602
# Epoch: 0261 cost = 7.870424455Test accuracy:  0.662
# Epoch: 0262 cost = 9.061816877Test accuracy:  0.593
# Epoch: 0263 cost = 8.119674553Test accuracy:  0.634
# Epoch: 0264 cost = 8.415653413Test accuracy:  0.597
# Epoch: 0265 cost = 7.932133328Test accuracy:  0.634
# Epoch: 0266 cost = 8.238037770Test accuracy:  0.588
# Epoch: 0267 cost = 10.255463741Test accuracy:  0.528
# Epoch: 0268 cost = 13.374195424Test accuracy:  0.509
# Epoch: 0269 cost = 14.170381633Test accuracy:  0.644
# Epoch: 0270 cost = 14.165485816Test accuracy:  0.639
# Epoch: 0271 cost = 9.704632174Test accuracy:  0.634
# Epoch: 0272 cost = 9.880413825Test accuracy:  0.519
# Epoch: 0273 cost = 9.316307393Test accuracy:  0.616
# Epoch: 0274 cost = 9.174489281Test accuracy:  0.639
# Epoch: 0275 cost = 13.851902398Test accuracy:  0.63
# Epoch: 0276 cost = 10.882097645Test accuracy:  0.583
# Epoch: 0277 cost = 10.502881809Test accuracy:  0.597
# Epoch: 0278 cost = 9.604959737Test accuracy:  0.583
# Epoch: 0279 cost = 8.440703013Test accuracy:  0.611
# Epoch: 0280 cost = 7.954636368Test accuracy:  0.616
# Epoch: 0281 cost = 8.659644961Test accuracy:  0.602
# Epoch: 0282 cost = 8.395809986Test accuracy:  0.616
# Epoch: 0283 cost = 8.490056677Test accuracy:  0.556
# Epoch: 0284 cost = 10.369210438Test accuracy:  0.597
# Epoch: 0285 cost = 15.233372645Test accuracy:  0.398
# Epoch: 0286 cost = 20.009037365Test accuracy:  0.63
# Epoch: 0287 cost = 16.607578061Test accuracy:  0.509
# Epoch: 0288 cost = 15.534191002Test accuracy:  0.662
# Epoch: 0289 cost = 11.671694951Test accuracy:  0.62
# Epoch: 0290 cost = 15.312851494Test accuracy:  0.606
# Epoch: 0291 cost = 16.235573075Test accuracy:  0.569
# Epoch: 0292 cost = 19.870172241Test accuracy:  0.565
# Epoch: 0293 cost = 27.063170693Test accuracy:  0.616
# Epoch: 0294 cost = 14.098332795Test accuracy:  0.639
# Epoch: 0295 cost = 10.481791323Test accuracy:  0.634
# Epoch: 0296 cost = 9.211279761Test accuracy:  0.648
# Epoch: 0297 cost = 9.608252937Test accuracy:  0.639
# Epoch: 0298 cost = 9.265808279Test accuracy:  0.616
# Epoch: 0299 cost = 8.569723725Test accuracy:  0.634
# Epoch: 0300 cost = 8.151568695Test accuracy:  0.63
# Epoch: 0301 cost = 8.155112678Test accuracy:  0.653
# Epoch: 0302 cost = 8.268106601Test accuracy:  0.634
# Epoch: 0303 cost = 8.293756583Test accuracy:  0.639
# Epoch: 0304 cost = 8.272203706Test accuracy:  0.62
# Epoch: 0305 cost = 8.093882712Test accuracy:  0.634
# Epoch: 0306 cost = 8.180596698Test accuracy:  0.634
# Epoch: 0307 cost = 7.917543119Test accuracy:  0.634
# Epoch: 0308 cost = 7.902236386Test accuracy:  0.62
# Epoch: 0309 cost = 8.223481796Test accuracy:  0.616
# Epoch: 0310 cost = 8.237594008Test accuracy:  0.639
# Epoch: 0311 cost = 10.014425072Test accuracy:  0.63
# Epoch: 0312 cost = 14.085449696Test accuracy:  0.63
# Epoch: 0313 cost = 13.057647813Test accuracy:  0.644
# Epoch: 0314 cost = 15.339633508Test accuracy:  0.62
# Epoch: 0315 cost = 13.518961365Test accuracy:  0.546
# Epoch: 0316 cost = 9.799856273Test accuracy:  0.639
# Epoch: 0317 cost = 7.779033563Test accuracy:  0.63
# Epoch: 0318 cost = 7.713567994Test accuracy:  0.63
# Epoch: 0319 cost = 7.657250263Test accuracy:  0.644
# Epoch: 0320 cost = 7.807190256Test accuracy:  0.625
# Epoch: 0321 cost = 7.867816535Test accuracy:  0.62
# Epoch: 0322 cost = 7.593383442Test accuracy:  0.62
# Epoch: 0323 cost = 7.751729711Test accuracy:  0.625
# Epoch: 0324 cost = 7.764666850Test accuracy:  0.611
# Epoch: 0325 cost = 7.753052896Test accuracy:  0.63
# Epoch: 0326 cost = 7.878985134Test accuracy:  0.634
# Epoch: 0327 cost = 8.041607716Test accuracy:  0.616
# Epoch: 0328 cost = 10.167768327Test accuracy:  0.639
# Epoch: 0329 cost = 8.448385802Test accuracy:  0.611
# Epoch: 0330 cost = 8.171431715Test accuracy:  0.597
# Epoch: 0331 cost = 8.665017085Test accuracy:  0.611
# Epoch: 0332 cost = 10.483446349Test accuracy:  0.611
# Epoch: 0333 cost = 7.925438036Test accuracy:  0.648
# Epoch: 0334 cost = 7.333718674Test accuracy:  0.653
# Epoch: 0335 cost = 9.112941590Test accuracy:  0.63
# Epoch: 0336 cost = 10.718102098Test accuracy:  0.616
# Epoch: 0337 cost = 8.356966772Test accuracy:  0.662
# Epoch: 0338 cost = 10.089305292Test accuracy:  0.556
# Epoch: 0339 cost = 8.632265611Test accuracy:  0.593
# Epoch: 0340 cost = 8.417037942Test accuracy:  0.625
# Epoch: 0341 cost = 8.819909020Test accuracy:  0.62
# Epoch: 0342 cost = 9.108202522Test accuracy:  0.602
# Epoch: 0343 cost = 8.647667516Test accuracy:  0.639
# Epoch: 0344 cost = 8.363827239Test accuracy:  0.63
# Epoch: 0345 cost = 8.257776434Test accuracy:  0.644
# Epoch: 0346 cost = 7.985789700Test accuracy:  0.62
# Epoch: 0347 cost = 8.385821342Test accuracy:  0.611
# Epoch: 0348 cost = 7.474301230Test accuracy:  0.611
# Epoch: 0349 cost = 7.732736024Test accuracy:  0.616
# Epoch: 0350 cost = 8.632832505Test accuracy:  0.63
# Epoch: 0351 cost = 15.691927606Test accuracy:  0.653
# Epoch: 0352 cost = 33.595048601Test accuracy:  0.648
# Epoch: 0353 cost = 18.852426746Test accuracy:  0.565
# Epoch: 0354 cost = 14.720395175Test accuracy:  0.616
# Epoch: 0355 cost = 11.264066349Test accuracy:  0.634
# Epoch: 0356 cost = 9.568612922Test accuracy:  0.653
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6e8d99582e5e> in <module>
#      13         batch_y = tr_labels[start:end]
#      14
# ---> 15         _, c = session.run([optimizer, loss_f], feed_dict={x: batch_x, y : batch_y})
#      16         avg_cost += c / total_batch
#      17
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(session, './cuav_rnn.ckpt')
print('Graph Saved! ')

# %%
def predict(file_source):
    print(file_source)
    data_to_predict = extract_features_for_predict(file_source)
    print(data_to_predict.shape)
    result_list = session.run(prediction_str, feed_dict={x: data_to_predict})
    print(result_list)
    result_list = list(result_list)
    label_count = {'others': 0, 'person': 0, 'car': 0, 'drone': 0,}
   
    total = 0
    for i, key in enumerate(list(label_count.keys())):
        label_count[key] = (result_list.count(i))
        print(key, int(label_count[key])/data_to_predict.shape[0])
    
    t = list(zip(list(label_count.values()), list(label_count.keys())))
    t.sort(reverse=True)
    print(t)
    print("")
        
    #for i in range(data_to_predict.shape[0]):
        #temp_output = session.run(prediction, feed_dict={x: data_to_predict[i]})
        #print(temp_output)

# %%
wav_file_path_test = 'C://slice_wav_data/testing/'
test_file_list = os.listdir(wav_file_path_test)
sample_test_file = wav_file_path_test + test_file_list[0]
for file in test_file_list:
    predict(wav_file_path_test + file)

# %%
sess = tf.InteractiveSession()
saver = tf.train.import_meta_graph('./cuav_rnn.ckpt.meta')
saver.restore(self.sess,'./cuav_rnn.ckpt.ckpt')
        
graph = tf.get_default_graph()
self.X =  self.sess.graph.get_tensor_by_name("Placeholder:0")
self.Y =  self.sess.graph.get_tensor_by_name("Placeholder_1:0")
